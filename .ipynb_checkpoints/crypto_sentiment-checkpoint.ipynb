# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\peeta\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q="bitcoin",
    language="en"
)

# %%
# Fetch the Ethereum news articles
ethereum_news = newsapi.get_everything(
    q="ethereum",
    language="en"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-05-10  Now, even though there are a number of women-f...    0.0772
# 1  2022-05-04  A Bitcoin mining site powered by otherwise los...   -0.0516
# 2  2022-04-14  Wikipedia editors have voted in favor of dropp...    0.4019
# 3  2022-05-02  Warren Buffett has always been a bitcoin skept...   -0.3269
# 4  2022-05-09  Image source, Getty Images\r\nThe value of Bit...    0.3400
#
#    positive  negative  neutral
# 0     0.036     0.000    0.964
# 1     0.056     0.061    0.882
# 2     0.088     0.000    0.912
# 3     0.085     0.143    0.772
# 4     0.072     0.000    0.928

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_news["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-04-14  The US Department of Treasury says Lazarus is ...   -0.7845
# 1  2022-05-10  Meta has revealed more of how NFTs will work o...    0.6486
# 2  2022-04-15  Opera launched its dedicated "Crypto Browser" ...    0.7351
# 3  2022-05-02  A multi-billion dollar cryptocurrency company ...   -0.2263
# 4  2022-05-04  When Bored Ape Yacht Club creators Yuga Labs a...   -0.2732
#
#    positive  negative  neutral
# 0     0.088     0.231    0.681
# 1     0.135     0.000    0.865
# 2     0.188     0.000    0.812
# 3     0.046     0.075    0.879
# 4     0.000     0.055    0.945

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.024585   0.070000   0.060600   0.869400
# std     0.407708   0.067763   0.061405   0.093083
# min    -0.549900   0.000000   0.000000   0.557000
# 25%    -0.335475   0.000000   0.000000   0.844250
# 50%     0.012800   0.064000   0.063000   0.894000
# 75%     0.355075   0.085750   0.077000   0.924250
# max     0.750600   0.202000   0.241000   0.964000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.092130   0.048850   0.067250   0.883900
# std     0.479428   0.065337   0.073266   0.076861
# min    -0.784500   0.000000   0.000000   0.681000
# 25%    -0.381800   0.000000   0.000000   0.827250
# 50%    -0.273200   0.000000   0.063000   0.921000
# 75%     0.303775   0.080500   0.077750   0.937000
# max     0.735100   0.188000   0.233000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin 0.007
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin 0.024585
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin 0.202000

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()
# Create a list of stopwords
sw = set(stopwords.words('english'))
# Expand the default stopwords list if necessary
# Char kept coming up so I added it as a stopword
sw_addons = {'char'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""    
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addons)]
    return tokens

# %%
# Create a new tokens column for Bitcoin
tokens = []
for text in bitcoin_df['text']:
    token=tokenizer(text)
    tokens.append(token)
bitcoin_df['tokens']=tokens
bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-05-10  Now, even though there are a number of women-f...    0.0772
# 1  2022-05-04  A Bitcoin mining site powered by otherwise los...   -0.0516
# 2  2022-04-14  Wikipedia editors have voted in favor of dropp...    0.4019
# 3  2022-05-02  Warren Buffett has always been a bitcoin skept...   -0.3269
# 4  2022-05-09  Image source, Getty Images\r\nThe value of Bit...    0.3400
#
#    positive  negative  neutral  \
# 0     0.036     0.000    0.964
# 1     0.056     0.061    0.882
# 2     0.088     0.000    0.912
# 3     0.085     0.143    0.772
# 4     0.072     0.000    0.928
#
#                                               tokens
# 0  [even, though, number, womenfocused, crypto, s...
# 1  [bitcoin, mining, site, powered, otherwise, lo...
# 2  [wikipedia, editor, voted, favor, dropping, cr...
# 3  [warren, buffett, ha, always, bitcoin, skeptic...
# 4  [image, source, getty, imagesthe, value, bitco...

# %%
# Create a new tokens column for Ethereum
tokens = []
for text in ethereum_df['text']:
    token=tokenizer(text)
    tokens.append(token)
ethereum_df['tokens']=tokens
ethereum_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-04-14  The US Department of Treasury says Lazarus is ...   -0.7845
# 1  2022-05-10  Meta has revealed more of how NFTs will work o...    0.6486
# 2  2022-04-15  Opera launched its dedicated "Crypto Browser" ...    0.7351
# 3  2022-05-02  A multi-billion dollar cryptocurrency company ...   -0.2263
# 4  2022-05-04  When Bored Ape Yacht Club creators Yuga Labs a...   -0.2732
#
#    positive  negative  neutral  \
# 0     0.088     0.231    0.681
# 1     0.135     0.000    0.865
# 2     0.188     0.000    0.812
# 3     0.046     0.075    0.879
# 4     0.000     0.055    0.945
#
#                                               tokens
# 0  [us, department, treasury, say, lazarus, behin...
# 1  [meta, ha, revealed, nfts, work, instagram, us...
# 2  [opera, launched, dedicated, crypto, browser, ...
# 3  [multibillion, dollar, cryptocurrency, company...
# 4  [bored, ape, yacht, club, creator, yuga, labs,...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
all_bitcoin_tokens=[]
for token in bitcoin_df['tokens']:
    all_bitcoin_tokens=all_bitcoin_tokens+token
bigram_bitcoin = Counter(ngrams(all_bitcoin_tokens, n=2))

# %%
print(bigram_bitcoin)
# Out:
# Counter({('reuters', 'bitcoin'): 5, ('previous', 'closebitcoin'): 4, ('closebitcoin', 'world'): 4, ('world', 'biggest'): 4, ('biggest', 'bestknown'): 4, ('bestknown', 'cryptocurrency'): 4, ('may', 'reuters'): 4, ('bitcoin', 'dropped'): 2, ('cryptocurrency', 'year'): 2, ('year', 'low'): 2, ('losing', 'previous'): 2, ('interest', 'rate'): 2, ('bitcoin', 'legal'): 2, ('legal', 'tender'): 2, ('el', 'salvador'): 2, ('credit', 'card'): 2, ('even', 'though'): 1, ('though', 'number'): 1, ('number', 'womenfocused'): 1, ('womenfocused', 'crypto'): 1, ('crypto', 'space'): 1, ('space', 'odeniran'): 1, ('odeniran', 'say'): 1, ('say', 'woman'): 1, ('woman', 'still'): 1, ('still', 'underrepresented'): 1, ('underrepresented', 'ive'): 1, ('ive', 'space'): 1, ('space', 'im'): 1, ('im', 'black'): 1, ('black', 'person'): 1, ('person', 'woman'): 1, ('woman', 'b'): 1, ('b', 'bitcoin'): 1, ('bitcoin', 'mining'): 1, ('mining', 'site'): 1, ('site', 'powered'): 1, ('powered', 'otherwise'): 1, ('otherwise', 'l
# ...

# %%
# Generate the Ethereum N-grams where N=2
all_ethereum_tokens=[]
for token in ethereum_df['tokens']:
    all_ethereum_tokens=all_ethereum_tokens+token
bigram_ethereum = Counter(ngrams(all_ethereum_tokens, n=2))

# %%
print(bigram_ethereum )
# Out:
# Counter({('reuters', 'bitcoin'): 4, ('previous', 'closebitcoin'): 4, ('closebitcoin', 'world'): 4, ('world', 'biggest'): 4, ('biggest', 'bestknown'): 4, ('bestknown', 'cryptocurrency'): 4, ('may', 'reuters'): 3, ('yacht', 'club'): 2, ('april', 'reuters'): 2, ('ha', 'promised'): 2, ('bitcoin', 'dropped'): 2, ('cryptocurrency', 'year'): 2, ('year', 'low'): 2, ('low', 'may'): 2, ('losing', 'previous'): 2, ('us', 'department'): 1, ('department', 'treasury'): 1, ('treasury', 'say'): 1, ('say', 'lazarus'): 1, ('lazarus', 'behind'): 1, ('behind', 'attackthe'): 1, ('attackthe', 'us'): 1, ('us', 'treasury'): 1, ('treasury', 'department'): 1, ('department', 'blame'): 1, ('blame', 'north'): 1, ('north', 'korean'): 1, ('korean', 'hacking'): 1, ('hacking', 'group'): 1, ('group', 'lazarus'): 1, ('lazarus', 'stealing'): 1, ('stealing', 'million'): 1, ('million', 'cryptocurrency'): 1, ('cryptocurrency', 'ronin'): 1, ('ronin', 'networ'): 1, ('networ', 'meta'): 1, ('meta', 'ha'): 1, ('ha', 'revealed')
# ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(all_bitcoin_tokens, 10)
# Out:
# [('cryptocurrency', 12),
#  ('bitcoin', 11),
#  ('ha', 6),
#  ('world', 6),
#  ('week', 5),
#  ('reuters', 5),
#  ('online', 4),
#  ('investor', 4),
#  ('dropped', 4),
#  ('previous', 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(all_ethereum_tokens, 10)
# Out:
# [('cryptocurrency', 7),
#  ('bitcoin', 7),
#  ('ha', 6),
#  ('ethereum', 6),
#  ('biggest', 5),
#  ('reuters', 5),
#  ('world', 5),
#  ('may', 5),
#  ('april', 4),
#  ('year', 4)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
bitcoin_wc = WordCloud().generate(' '.join(all_bitcoin_tokens))
plt.imshow(bitcoin_wc)

# %%
# Generate the Ethereum word cloud
ethereum_wc = WordCloud().generate(' '.join(all_ethereum_tokens))
plt.imshow(ethereum_wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
all_bitcoin_text=''
for text in bitcoin_df['text']:
    all_bitcoin_text += text

# %%
all_bitcoin_text
# Out:
# 'Now, even though there are a number of women-focused crypto spaces, Odeniran says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars]A Bitcoin mining site powered by otherwise lost gas from an oil well near Linden, Texas, on April 4th, 2022. | Photo by FRANCOIS PICARD/AFP via Getty Images\r\n\n \n\n Of all the corporate climate hype fl… [+6544 chars]Wikipedia editors have voted in favor of dropping cryptocurrency from the Wikimedia Foundation\'s donation options. As Ars Technica reports, an editor for the online encyclopedia called GorillaWarfare… [+1577 chars]Warren Buffett has always been a bitcoin skeptic. But the billionaire investor had his most harsh words yet for the cryptocurrency over the weekend. Buffett made it clear that his opposition to crypt… [+2297 chars]Image source, Getty Images\r\nThe value of Bitcoin continued to fall over the weekend as it dropped below $34,000 (£27,630), according 
# ...

# %%
# Run the NER processor on all of the text
doc = nlp(all_bitcoin_text)

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Now, even though there are a number of women-focused crypto spaces,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Odeniran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  says women are still underrepresented. Ive been in spaces where Im the only Black person, or the only woman, or the only B… [+3828 chars]A Bitcoin mining site powered by otherwise lost gas from an oil well near
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# ...

# %%
# List all Entities
entities = [ent.text for ent in doc.ents]

# %%
print(entities)
# Out:
# ['Odeniran', 'Linden', 'Texas', 'April 4th', '2022', 'FRANCOIS PICARD/AFP', 'Getty Images', "the Wikimedia Foundation's", 'Ars Technica', 'GorillaWarfare', 'Buffett', 'the weekend', 'Buffett', 'Getty Images', 'the weekend', '34,000', '27,630', 'Coinbase', 'Last week', 'Fidelity Investments', 'the US Treasury', 'Reuters', '5.1%', '38,391.36', 'Tuesday', '2,229.82', 'Bitcoin', '16%', 'year', '+339', 'Reuters', '5.7%', '39,862.84', 'Wednesday', '2,102.94', 'Bitcoin', '20.9%', 'year', 'Bitcoin', 'Gucci', 'week', 'Kristy Kilburn', 'May 11', 'Reuters', '7.23%', '28,758.29', '22:05 GMT', 'Wednesday', '2,241.68', 'Bitcoin', '40.4%', '+361', 'last July', '33,000', 'the week', 'last week', 'Fed', '9', 'Reuters', '7.81%', '31,333.41', 'Monday', '2,655.98', 'Bitcoin', '35%', 'AMC', 'April 15', 'AMC', 'Adam Aron', 'moviego', 'Mexican', 'North London', 'a few weeks ago', 'Crypto Browser', 'January', 'Windows, Mac', 'Android', 'Reuters', '+4315', 'Central African Republic', 'second', 'El Salvador',
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
all_ethereum_text=''
for text in ethereum_df['text']:
    all_ethereum_text += text

# %%
# Run the NER processor on all of the text
doc_2 = nlp(all_ethereum_text)

# %%
# Render the visualization
displacy.render(doc_2, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The US Department of Treasury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  says
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lazarus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The US Treasury Department
# ...

# %%
# List all Entities
entities = [ent.text for ent in doc_2.ents]

# %%
print(entities)
# Out:
# ['The US Department of Treasury', 'Lazarus', 'The US Treasury Department', 'North Korean', 'Lazarus', '$625 million', 'Ronin', 'Instagram', 'US', 'Instagram', 'Crypto Browser', 'January', 'Windows, Mac', 'Android', 'Ethereum', 'Yuga Labs', 'Bored Ape Yacht Club', 'Yuga Labs', 'Otherside', 'April 30', 'NFT', 'Ethereum', 'more than five years', '100,000', 'North Korea', 'US', 'NBC News', 'Reuters', 'No.2', 'second', 'AMC', 'April 15', 'AMC', 'Adam Aron', 'moviego', 'the "Bored Apes Yacht Club', 'Last night', 'Bloomberg', 'nearly a third', 'a billion dollars', 'this week', 'the Ukrainian Computer Emergency Response Team', 'Slovakian', 'Russia', 'GRU Sandworm', 'chars]40 days ago', '47,454', '34,007', '28%.About a third', 'this week', 'Ethereum', 'Merge', 'a few months after June', 'a year and a half ago', 'The Order Flow', 'Dan Robinson', "Georgios Konstantopoulos'", 'Ethereum', 'Dark Forest', 'August 20', '26', 'Reuters', '5.1%', '38,391.36', 'Tuesday', '2,229.82', 'Bitcoin', '16%', 'y
# ...

# %% [markdown]
# ---
